# %% [markdown]
# # Environment & Project Sanity Check
#
# **Updated:** 2026-03-03
# **Goal**: confirm Python version and that the sample CSV loads correctly.

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Mar  3 2026, 18:22:04) [Clang 17.0.0 (clang-1700.0.13.3)]'

# %%
import pandas as pd

df = pd.read_csv("../data/sample_pnl.csv")
df.head()
# Out:
#      pnl
# 0  0.015
# 1 -0.020
# 2  0.005
# 3 -0.010
# 4  0.012

# %%
print("rows:", len(df), "cols:", df.columns.tolist())
# Out:
# rows: 10 cols: ['pnl']

# %% [markdown]
# ## Summary
# - Confirmed the notebook is using the expected Python interpreter (`.venv`).
# - Loaded `data/sample_pnl.csv` successfully and verified the `pnl` column.
# - Environment is ready for running the CLI and pytest in a reproducible way.
